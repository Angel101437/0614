# %% [markdown]
# <a href="https://colab.research.google.com/github/Angel101437/0614/blob/main/%E3%80%8Cfaster_whisper_youtube_ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Youtube Videos Transcription with Faster Whisper**
#
#
# [![notebook shield](https://img.shields.io/static/v1?label=&message=Notebook&color=blue&style=for-the-badge&logo=googlecolab&link=https://colab.research.google.com/github/ArthurFDLR/whisper-youtube/blob/main/whisper_youtube.ipynb)](https://colab.research.google.com/github/lewangdev/whisper-youtube/blob/main/faster_whisper_youtube.ipynb)
# [![repository shield](https://img.shields.io/static/v1?label=&message=Repository&color=blue&style=for-the-badge&logo=github&link=https://github.com/lewangdev/faster_whisper_youtube)](https://github.com/lewangdev/faster_whisper_youtube)
#
#
# [faster-whisper](https://github.com/guillaumekln/faster-whisper) is a reimplementation of OpenAI's Whisper model using CTranslate2, which is a fast inference engine for Transformer models.
#
# This implementation is up to 4 times faster than openai/whisper for the same accuracy while using less memory. The efficiency can be further improved with 8-bit quantization on both CPU and GPU.
#
# Whisper is a general-purpose speech recognition model. It is trained on a large dataset of diverse audio and is also a multi-task model that can perform multilingual speech recognition as well as speech translation and language identification.
#
# This Notebook will guide you through the transcription of a Youtube video using Faster Whisper. You'll be able to explore most inference parameters or use the Notebook as-is to store the transcript and video audio in your Google Drive.

# %%
#@markdown # **Check GPU type** 🕵️

#@markdown The type of GPU you get assigned in your Colab session defined the speed at which the video will be transcribed.
#@markdown The higher the number of floating point operations per second (FLOPS), the faster the transcription.
#@markdown But even the least powerful GPU available in Colab is able to run any Whisper model.
#@markdown Make sure you've selected `GPU` as hardware accelerator for the Notebook (Runtime &rarr; Change runtime type &rarr; Hardware accelerator).

#@markdown |  GPU   |  GPU RAM   | FP32 teraFLOPS |     Availability   |
#@markdown |:------:|:----------:|:--------------:|:------------------:|
#@markdown |  T4    |    16 GB   |       8.1      |         Free       |
#@markdown | P100   |    16 GB   |      10.6      |      Colab Pro     |
#@markdown | V100   |    16 GB   |      15.7      |  Colab Pro (Rare)  |

#@markdown ---
#@markdown **Factory reset your Notebook's runtime if you want to get assigned a new GPU.**

# !nvidia-smi -L

# !nvidia-smi
# Out:
# GPU 0: Tesla T4 (UUID: GPU-fb915b2b-d8aa-d6f2-f1d3-0c4841cb64fc)
# Fri Jun  9 16:41:01 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#@markdown # **Install libraries** 🏗️
#@markdown This cell will take a little while to download several libraries, including Faster Whisper.

#@markdown ---

! pip install faster-whisper
! pip install yt-dlp

import sys
import warnings
from faster_whisper import WhisperModel
from pathlib import Path
import yt_dlp
import subprocess
import torch
import shutil
import numpy as np
from IPython.display import display, Markdown, YouTubeVideo

device = torch.device('cuda:0')
print('Using device:', device, file=sys.stderr)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting faster-whisper
#   Downloading faster_whisper-0.6.0-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 28.3 MB/s eta 0:00:00
# Collecting av==10.* (from faster-whisper)
#   Downloading av-10.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.0/31.0 MB 35.6 MB/s eta 0:00:00
# Collecting ctranslate2<4,>=3.10 (from faster-whisper)
#   Downloading ctranslate2-3.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.2/33.2 MB 17.9 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.13 (from faster-whisper)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 27.2 MB/s eta 0:00:00
# Collecting tokenizers==0.13.* (from faster-whisper)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 110.4 MB/s eta 0:00:00
# Collecting onnxruntime<2,>=1.14 (from faster-whisper)
#   Downloading onnxruntime-1.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 121.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ctranslate2<4,>=3.10->faster-whisper) (1.22.4)
# Requirement already satisfied: pyyaml<7,>=5.3 in /usr/local/lib/python3.10/dist-packages (from ctranslate2<4,>=3.10->faster-whisper) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper) (3.12.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper) (2023.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper) (2.27.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper) (23.1)
# Collecting coloredlogs (from onnxruntime<2,>=1.14->faster-whisper)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (23.3.3)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (1.11.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime<2,>=1.14->faster-whisper)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime<2,>=1.14->faster-whisper) (1.3.0)
# Installing collected packages: tokenizers, av, humanfriendly, ctranslate2, huggingface-hub, coloredlogs, onnxruntime, faster-whisper
# Successfully installed av-10.0.0 coloredlogs-15.0.1 ctranslate2-3.15.1 faster-whisper-0.6.0 huggingface-hub-0.15.1 humanfriendly-10.0 onnxruntime-1.15.0 tokenizers-0.13.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yt-dlp
#   Downloading yt_dlp-2023.3.4-py2.py3-none-any.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 45.8 MB/s eta 0:00:00
# Collecting mutagen (from yt-dlp)
#   Downloading mutagen-1.46.0-py3-none-any.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 24.5 MB/s eta 0:00:00
# Collecting pycryptodomex (from yt-dlp)
#   Downloading pycryptodomex-3.18.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 90.3 MB/s eta 0:00:00
# Collecting websockets (from yt-dlp)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (2022.12.7)
# Collecting brotli (from yt-dlp)
#   Downloading Brotli-1.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 97.3 MB/s eta 0:00:00
# Installing collected packages: brotli, websockets, pycryptodomex, mutagen, yt-dlp
# Successfully installed brotli-1.0.9 mutagen-1.46.0 pycryptodomex-3.18.0 websockets-11.0.3 yt-dlp-2023.3.4
# Using device: cuda:0

# %%
#@markdown # **Optional:** Save data in Google Drive 💾
#@markdown Enter a Google Drive path and run this cell if you want to store the results inside Google Drive.

# Uncomment to copy generated images to drive, faster than downloading directly from colab in my experience.
from google.colab import drive
drive_mount_path = Path("/") / "content" / "drive"
drive.mount(str(drive_mount_path))
drive_mount_path /= "My Drive"
#@markdown ---
drive_path = "output" #@param {type:"string"}
#@markdown ---
#@markdown **Run this cell again if you change your Google Drive path.**

drive_whisper_path = drive_mount_path / Path(drive_path.lstrip("/"))
drive_whisper_path.mkdir(parents=True, exist_ok=True)
# Out:
# Mounted at /content/drive

# %%
#@markdown # **Model selection** 🧠

#@markdown As of the first public release, there are 4 pre-trained options to play with:

#@markdown |  Size  | Parameters | English-only model | Multilingual model | Required VRAM | Relative speed |
#@markdown |:------:|:----------:|:------------------:|:------------------:|:-------------:|:--------------:|
#@markdown |  tiny  |    39 M    |     `tiny.en`      |       `tiny`       |     ~0.8 GB     |      ~32x      |
#@markdown |  base  |    74 M    |     `base.en`      |       `base`       |     ~1.0 GB     |      ~16x      |
#@markdown | small  |   244 M    |     `small.en`     |      `small`       |     ~1.4 GB     |      ~6x       |
#@markdown | medium |   769 M    |    `medium.en`     |      `medium`      |     ~2.7 GB     |      ~2x       |
#@markdown | large-v1  |   1550 M   |        N/A         |      `large-v1`       |    ~4.3 GB     |       1x       |
#@markdown | large-v2  |   1550 M   |        N/A         |      `large-v2`       |    ~4.3 GB     |       1x       |

#@markdown ---
model_size = 'large-v2' #@param ['tiny', 'tiny.en', 'base', 'base.en', 'small', 'small.en', 'medium', 'medium.en', 'large-v1', 'large-v2']
device_type = "cuda" #@param {type:"string"} ['cuda', 'cpu']
compute_type = "float16" #@param {type:"string"} ['float16', 'int8_float16', 'int8']
#@markdown ---
#@markdown **Run this cell again if you change the model.**

model = WhisperModel(model_size, device=device_type, compute_type=compute_type)
# Out:
# Downloading model.bin:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# Downloading (…)37e8b/tokenizer.json:   0%|          | 0.00/2.20M [00:00<?, ?B/s]
# Downloading (…)08837e8b/config.json:   0%|          | 0.00/2.80k [00:00<?, ?B/s]
# Downloading (…)37e8b/vocabulary.txt:   0%|          | 0.00/460k [00:00<?, ?B/s]

# %%
#@markdown # **Video selection** 📺

#@markdown Enter the URL of the Youtube video you want to transcribe, wether you want to save the audio file in your Google Drive, and run the cell.

Type = "Google Drive" #@param ['Youtube video or playlist', 'Google Drive']
#@markdown ---
#@markdown #### **Youtube video or playlist**
URL = "https://drive.google.com/file/d/1cfymLrEPcpIxyEzr_W1xz_M-P9aDL1uc/view?usp=drive_link" #@param {type:"string"}
# store_audio = True #@param {type:"boolean"}
#@markdown ---
#@markdown #### **Google Drive video, audio (mp4, wav), or folder containing video and/or audio files**
video_path = "Colab Notebooks/1101\u53F0\u6CE5_2018Q1_6\u6CD5\u4EBA\u8AAA\u660E\u6703_20180515.mp4" #@param {type:"string"}
#@markdown ---
#@markdown **Run this cell again if you change the video.**

video_path_local_list = []

if Type == "Youtube video or playlist":

    ydl_opts = {
        'format': 'm4a/bestaudio/best',
        'outtmpl': '%(id)s.%(ext)s',
        # ℹ️ See help(yt_dlp.postprocessor) for a list of available Postprocessors and their arguments
        'postprocessors': [{  # Extract audio using ffmpeg
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'wav',
        }]
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        error_code = ydl.download([URL])
        list_video_info = [ydl.extract_info(URL, download=False)]

    for video_info in list_video_info:
        video_path_local_list.append(Path(f"{video_info['id']}.wav"))

elif Type == "Google Drive":
    # video_path_drive = drive_mount_path / Path(video_path.lstrip("/"))
    video_path = drive_mount_path / Path(video_path.lstrip("/"))
    if video_path.is_dir():
        for video_path_drive in video_path.glob("**/*"):
            if video_path_drive.is_file():
                display(Markdown(f"**{str(video_path_drive)} selected for transcription.**"))
            elif video_path_drive.is_dir():
                display(Markdown(f"**Subfolders not supported.**"))
            else:
                display(Markdown(f"**{str(video_path_drive)} does not exist, skipping.**"))
            video_path_local = Path(".").resolve() / (video_path_drive.name)
            shutil.copy(video_path_drive, video_path_local)
            video_path_local_list.append(video_path_local)
    elif video_path.is_file():
        video_path_local = Path(".").resolve() / (video_path.name)
        shutil.copy(video_path, video_path_local)
        video_path_local_list.append(video_path_local)
        display(Markdown(f"**{str(video_path)} selected for transcription.**"))
    else:
        display(Markdown(f"**{str(video_path)} does not exist.**"))

else:
    raise(TypeError("Please select supported input type."))

for video_path_local in video_path_local_list:
    if video_path_local.suffix == ".mp4":
        video_path_local = video_path_local.with_suffix(".wav")
        result  = subprocess.run(["ffmpeg", "-i", str(video_path_local.with_suffix(".mp4")), "-vn", "-acodec", "pcm_s16le", "-ar", "16000", "-ac", "1", str(video_path_local)])
# Out:
# **/content/drive/My Drive/Colab Notebooks/1101台泥_2018Q1_6法人說明會_20180515.mp4 selected for transcription.**

# %%
def seconds_to_time_format(s):
    # Convert seconds to hours, minutes, seconds, and milliseconds
    hours = s // 3600
    s %= 3600
    minutes = s // 60
    s %= 60
    seconds = s // 1
    milliseconds = round((s % 1) * 1000)

    # Return the formatted string
    return f"{int(hours):02d}:{int(minutes):02d}:{int(seconds):02d},{int(milliseconds):03d}"

#@markdown # **Run the model** 🚀

#@markdown Run this cell to execute the transcription of the video. This can take a while and very based on the length of the video and the number of parameters of the model selected above.

#@markdown ## **Parameters** ⚙️

#@markdown ### **Behavior control**
#@markdown #### Language
language = "zh" #@param ["auto", "en", "zh", "ja", "fr", "de"] {allow-input: true}
#@markdown #### initial prompt
initial_prompt = "Please do not translate, only transcription be allowed. " #@param {type:"string"}
#@markdown ---
#@markdown #### Word-level timestamps
word_level_timestamps = False #@param {type:"boolean"}
#@markdown ---
#@markdown #### VAD filter
vad_filter = True #@param {type:"boolean"}
vad_filter_min_silence_duration_ms = 50 #@param {type:"integer"}
#@markdown ---
#@markdown #### Output(Default is srt, txt if `text_only` be checked )
text_only = True #@param {type:"boolean"}


segments, info = model.transcribe(str(video_path_local), beam_size=5,
                                  language=None if language == "auto" else language,
                                  initial_prompt=initial_prompt,
                                  word_timestamps=word_level_timestamps,
                                  vad_filter=vad_filter,
                                  vad_parameters=dict(min_silence_duration_ms=vad_filter_min_silence_duration_ms))

display(Markdown(f"Detected language '{info.language}' with probability {info.language_probability}"))

ext_name = '.txt' if text_only else ".srt"
transcript_file_name = video_path_local.stem + ext_name
sentence_idx = 1
with open(transcript_file_name, 'w') as f:
  for segment in segments:
    if word_level_timestamps:
      for word in segment.words:
        ts_start = seconds_to_time_format(word.start)
        ts_end = seconds_to_time_format(word.end)
        print(f"[{ts_start} --> {ts_end}] {word.word}")
        if not text_only:
          f.write(f"{sentence_idx}\n")
          f.write(f"{ts_start} --> {ts_end}\n")
          f.write(f"{word.word}\n\n")
        else:
          f.write(f"{word.word}")
        f.write("\n")
        sentence_idx = sentence_idx + 1
    else:
      ts_start = seconds_to_time_format(segment.start)
      ts_end = seconds_to_time_format(segment.end)
      print(f"[{ts_start} --> {ts_end}] {segment.text}")
      if not text_only:
        f.write(f"{sentence_idx}\n")
        f.write(f"{ts_start} --> {ts_end}\n")
        f.write(f"{segment.text.strip()}\n\n")
      else:
        f.write(f"{segment.text.strip()}\n")
      sentence_idx = sentence_idx + 1

try:
  shutil.copy(video_path_local.parent / transcript_file_name,
            drive_whisper_path / transcript_file_name
  )
  display(Markdown(f"**Transcript file created: {drive_whisper_path / transcript_file_name}**"))
except:
  display(Markdown(f"**Transcript file created: {video_path_local.parent / transcript_file_name}**"))
# Out:
# Detected language 'zh' with probability 1
# [00:00:00,260 --> 00:00:04,000] 以動荒園林的合作的這個核實開始進作
# [00:00:04,000 --> 00:00:08,000] 第一個這個笑紅樹的開花呢
# [00:00:08,000 --> 00:00:13,000] 我們台北市跟這個工研院的綠能所跟生醫所合作
# [00:00:13,000 --> 00:00:14,000] 分開
# [00:00:14,000 --> 00:00:16,500] 那這一期的合作是兩年
# [00:00:16,500 --> 00:00:18,000] 今年是進入第二年
# [00:00:18,000 --> 00:00:21,000] 那跟綠能所的合作是
# [00:00:21,000 --> 00:00:24,000] 怎麼樣子把這個笑紅樹的這個雨生紅菽草
# [00:00:24,000 --> 00:00:25,000] 怎麼樣子養快
# [00:00:25,000 --> 00:00:26,000] 它會加速
# [00:00:26,000 --> 00:00:28,000] 加入一些微量的元素
# [00:00:28,000 --> 00:00:32,000] 那當然這個除了雨生紅菽草之外呢
# [00:00:32,000 --> 00:00:36,000] 我們也有其他這個生殖酒精的這個藻類
# [00:00:36,000 --> 00:00:40,000] 那跟這個生醫所的合作
# [00:00:40,000 --> 00:00:43,000] 是他們去研發這個笑紅樹的應用
# [00:00:43,000 --> 00:00:46,000] 那這個在化妝品也好
# [00:00:46,000 --> 00:00:48,000] 或者是這個保健食品
# [00:00:48,000 --> 00:00:51,000] 他們研究這些安全性跟這個用途
# [00:00:51,000 --> 00:00:53,000] 那這個因為牽涉比較細節
# [00:00:53,000 --> 00:00:54,000] 我就不再講
# [00:00:54,000 --> 00:00:55,000] 不過呢
# [00:00:55,000 --> 00:00:58,000] 董事長是有這個指示就是說
# [00:00:58,000 --> 00:01:01,000] 繼續怎麼樣子去消化這個二氧化碳大量一點
# [00:01:01,000 --> 00:01:04,000] 所以怎麼樣子再尋求其他的藻類
# [00:01:04,000 --> 00:01:08,000] 能夠這個應用的價值
# [00:01:08,000 --> 00:01:10,000] 可能在食品上面也可以
# [00:01:10,000 --> 00:01:12,000] 但是怎麼樣能夠這個大量
# [00:01:12,000 --> 00:01:14,000] 這個消化這個二氧化碳
# [00:01:14,000 --> 00:01:17,000] 是我們這個下一階段在進行的
# [00:01:17,000 --> 00:01:19,100] 那另外一個問題就是說
# [00:01:19,100 --> 00:01:22,100] 你東方園林合作何時開始運作
# [00:01:22,100 --> 00:01:24,100] 以及貢獻營收
# [00:01:24,100 --> 00:01:26,100] 那我們在今年的1月23號呢
# [00:01:26,100 --> 00:01:29,100] 跟這個北京的東方園林
# [00:01:29,100 --> 00:01:31,100] 簽了戰略合作協議
# [00:01:31,100 --> 00:01:34,100] 那簽約以後我們雙方呢
# [00:01:34,100 --> 00:01:36,100] 就組織了這個團隊到
# [00:01:36,100 --> 00:01:41,100] 台北在大陸的十幾家子公司
# [00:01:41,100 --> 00:01:43,100] 地區性的去調查
# [00:01:43,100 --> 00:01:48,100] 那到底這些有多少的違規的這個量
# [00:01:48,100 --> 00:01:49,100] 那目前呢
# [00:01:49,100 --> 00:01:51,100] 這個已經鎖定
# [00:01:51,100 --> 00:01:55,700] 就是說這個比較急迫性的
# [00:01:55,700 --> 00:01:57,700] 可以去展開的
# [00:01:57,700 --> 00:02:01,700] 我們大概現在有三個省
# [00:02:01,700 --> 00:02:03,700] 那在華南有兩個
# [00:02:03,700 --> 00:02:05,700] 在西南有一個
# [00:02:05,700 --> 00:02:07,700] 那我們目前已經正在
# [00:02:07,700 --> 00:02:09,700] 登記這個合資公司之中
# [00:02:09,700 --> 00:02:11,700] 那後來的話就會進行這個立項
# [00:02:11,700 --> 00:02:14,700] 跟這個環評的作業
# [00:02:14,700 --> 00:02:17,700] 我們一定希望這環評作業取得許可
# [00:02:17,700 --> 00:02:19,700] 能夠在第四季的時候
# [00:02:19,700 --> 00:02:21,700] 之前能夠完成
# [00:02:21,700 --> 00:02:23,700] 然後我們第四季來建設
# [00:02:23,700 --> 00:02:25,700] 在明年初的時候能夠投入生產
# [00:02:25,700 --> 00:02:30,700] 那因為這個是每個區域的量是不一定的
# [00:02:30,700 --> 00:02:32,700] 所以在營收的部分呢
# [00:02:32,700 --> 00:02:34,700] 我們沒有辦法去預測
# [00:02:34,700 --> 00:02:35,700] 但是呢
# [00:02:35,700 --> 00:02:38,700] 這個處理違規它的一噸呢
# [00:02:38,700 --> 00:02:39,700] 在平均的話
# [00:02:39,700 --> 00:02:42,700] 在大陸就是人民幣一千塊到兩千五
# [00:02:42,700 --> 00:02:45,700] 所以如果是我們用這個比重來講
# [00:02:45,700 --> 00:02:47,700] 是每噸一千五百塊的話
# [00:02:47,700 --> 00:02:50,700] 它比我們一般處理生活垃圾
# [00:02:50,700 --> 00:02:52,700] 一噸一百五十塊到兩百塊
# [00:02:52,700 --> 00:02:55,700] 事實上這個效益相對比較大
# [00:02:55,700 --> 00:02:56,700] 以上回答這個問題
# [00:02:56,700 --> 00:02:57,700] 謝謝
# [00:02:59,700 --> 00:03:02,980] 快兩個鐘頭了
# [00:03:02,980 --> 00:03:04,980] 不知道各位還有什麼問題
# [00:03:10,020 --> 00:03:13,140] 剛剛有漏掉一個問題
# [00:03:13,140 --> 00:03:16,140] 有人在問說這個
# [00:03:16,140 --> 00:03:18,140] 十五萬噸的產品
# [00:03:18,140 --> 00:03:19,140] 印度開出來的話
# [00:03:19,140 --> 00:03:23,140] 約需幾條輪胎可以用掉
# [00:03:23,140 --> 00:03:25,140] 這個問題問得很好
# [00:03:25,140 --> 00:03:27,140] 要消化掉這個碳油
# [00:03:27,140 --> 00:03:31,140] 那我們這個精算團隊大概算了一下
# [00:03:31,140 --> 00:03:34,140] 這個汽車胎帶
# [00:03:34,140 --> 00:03:36,140] 一個輪胎要兩到三公斤
# [00:03:36,140 --> 00:03:39,140] 卡車胎要十八到二十公斤
# [00:03:39,140 --> 00:03:41,140] 所以推算了大概平均
# [00:03:41,140 --> 00:03:44,140] 要六千到七六萬輪胎
# [00:03:44,140 --> 00:03:46,300] 那我根據現在計算
# [00:03:46,300 --> 00:03:49,300] 印度境內的輪胎生產
# [00:03:49,300 --> 00:03:52,300] 大概有三到四億條
# [00:03:52,300 --> 00:03:55,300] 未來擴充可能有倍增
# [00:03:55,300 --> 00:03:58,300] 所以我相信這個消化是沒有問題的
# [00:03:58,300 --> 00:04:01,670] 那另外有提到說
# [00:04:01,670 --> 00:04:04,670] 能源的這個獲利的問題
# [00:04:04,670 --> 00:04:09,670] 我相信第二季以後的足跡會
# [00:04:09,670 --> 00:04:13,670] 應該是有信心越來越好
# [00:04:14,670 --> 00:04:18,670] 那提到鑰匙上市的問題
# [00:04:18,670 --> 00:04:20,670] 這是一個水到渠成的問題
# [00:04:20,670 --> 00:04:22,670] 那基礎都建立之後
# [00:04:22,670 --> 00:04:26,090] 那自然會水到渠成
# [00:04:26,090 --> 00:04:28,090] 那其他大概都是對於
# [00:04:28,090 --> 00:04:32,090] 短期獲利的一些問題
# [00:04:32,090 --> 00:04:37,090] 我想這部分能不能油價的上漲
# [00:04:37,090 --> 00:04:38,090] 就是全球油價的上漲
# [00:04:38,090 --> 00:04:41,090] 有問到都是可以全部反映
# [00:04:41,090 --> 00:04:44,090] 這個我想跟每家客戶
# [00:04:44,090 --> 00:04:46,090] 跟我們的競爭力有關
# [00:04:46,090 --> 00:04:49,090] 是不是可以反映到每一家客戶
# [00:04:49,090 --> 00:04:50,090] 看我們客戶
# [00:04:50,090 --> 00:04:54,090] 不同的客戶跟不同的產品品質來看
# [00:04:54,090 --> 00:04:58,090] 所以這個問題也滿難一概而論
# [00:04:58,090 --> 00:05:00,090] 那大概就講這個
# [00:05:06,290 --> 00:05:09,290] 其實很多人在電子方面會提這個問題
# [00:05:09,290 --> 00:05:12,290] 我想稍微幫各位澆點冷水
# [00:05:13,290 --> 00:05:14,290] 電池沒有錯
# [00:05:14,290 --> 00:05:15,290] 能源是第一季賺錢
# [00:05:15,290 --> 00:05:18,290] 今年大概問題也不是太大
# [00:05:18,290 --> 00:05:20,290] 可是我們要看能源
# [00:05:20,290 --> 00:05:21,290] 不是看今年
# [00:05:21,290 --> 00:05:23,290] 甚至於明年甚至於後年
# [00:05:23,290 --> 00:05:25,290] 因為這兩三年的
# [00:05:25,290 --> 00:05:27,290] 我們可以看到的這個vision
# [00:05:27,290 --> 00:05:28,290] 是看得到的
# [00:05:28,290 --> 00:05:31,290] 重點是三年兩年半到三年以後
# [00:05:31,290 --> 00:05:32,290] 怎麼回事
# [00:05:32,290 --> 00:05:35,290] 因為現在可以生產2170的廠
# [00:05:35,290 --> 00:05:36,290] 全世界有幾個
# [00:05:36,290 --> 00:05:37,290] 我們只在內
# [00:05:37,290 --> 00:05:38,290] which means它的energy density
# [00:05:38,290 --> 00:05:39,290] 它的安全度
# [00:05:39,290 --> 00:05:40,290] 一切東西都可以達標的
# [00:05:40,290 --> 00:05:41,290] 其實不多
# [00:05:41,290 --> 00:05:42,290] 可是重點
# [00:05:42,290 --> 00:05:44,290] 斯登的這個電池
# [00:05:44,290 --> 00:05:47,290] 是不是他的唯一的未來
# [00:05:47,290 --> 00:05:48,290] 我們現在車子上面
# [00:05:48,290 --> 00:05:50,290] 他方電池大方電池也小
# [00:05:50,290 --> 00:05:51,290] 泡池也有
# [00:05:51,290 --> 00:05:53,290] 到底什麼方向其實不知道
# [00:05:53,290 --> 00:05:56,290] 所以說變成能源能不能成功
# [00:05:56,290 --> 00:05:58,290] 能不能夠上市
# [00:05:58,290 --> 00:06:00,290] 這個講實在話對我來講還早
# [00:06:00,290 --> 00:06:02,290] 因為我必須要看我new out
# [00:06:02,290 --> 00:06:03,290] 我今天R&D
# [00:06:03,290 --> 00:06:05,290] 我為什麼能源在花時間做R&D
# [00:06:05,290 --> 00:06:08,290] 因為這個是看不清楚的
# [00:06:08,290 --> 00:06:10,290] 我真的完全不了解
# [00:06:10,290 --> 00:06:12,290] 我們現在的路對與不對
# [00:06:12,290 --> 00:06:14,290] 所以說我們在花相當多的時間
# [00:06:14,290 --> 00:06:16,290] 也有苦心的人進來走這個路
# [00:06:16,290 --> 00:06:17,290] 也跟各位報告
# [00:06:17,290 --> 00:06:21,290] 我們現在面對的競爭者
# [00:06:21,290 --> 00:06:23,290] 要不是大廠
# [00:06:23,290 --> 00:06:25,290] 要不就是中國大陸的國家隊
# [00:06:25,290 --> 00:06:27,290] 我們能源是非常非常小
# [00:06:27,290 --> 00:06:29,290] 他們隨便談一談
# [00:06:29,290 --> 00:06:30,290] 你也看到一些數據
# [00:06:30,290 --> 00:06:31,290] 澳洲搞一個廠
# [00:06:31,290 --> 00:06:32,290] 十億美金
# [00:06:32,290 --> 00:06:34,290] 所以這個數字不是一回事
# [00:06:34,290 --> 00:06:36,290] 所以我們變成又在小的裡面
# [00:06:36,290 --> 00:06:37,290] 要play the game
# [00:06:37,290 --> 00:06:39,290] 看看我們怎麼role play
# [00:06:39,290 --> 00:06:41,290] 成不成功我不知道
# [00:06:41,290 --> 00:06:42,290] 可是是有機會
# [00:06:42,290 --> 00:06:44,290] 而就是有這個機會
# [00:06:44,290 --> 00:06:46,290] 我們想辦法走走看
# [00:06:46,290 --> 00:06:48,290] 我們有一些base
# [00:06:48,290 --> 00:06:49,290] 不錯的base
# [00:06:49,290 --> 00:06:51,290] 但是未來能不能成功
# [00:06:51,290 --> 00:06:53,290] 只能講說
# [00:06:53,290 --> 00:06:57,290] 一部分看75%看天
# [00:06:57,290 --> 00:06:59,290] 25%看我們做多少的努力
# [00:06:59,290 --> 00:07:01,290] 但是能源真的不是那麼清楚
# [00:07:01,290 --> 00:07:03,290] 什麼多久就上市的問題
# [00:07:03,290 --> 00:07:04,290] 短期壯實沒有什麼意義
# [00:07:04,290 --> 00:07:06,290] 而且我不是很喜歡
# [00:07:06,290 --> 00:07:07,290] 上市一個公司失敗了
# [00:07:07,290 --> 00:07:10,290] 造成很多投資者的損失
# [00:07:10,290 --> 00:07:11,290] 這個我心理上
# [00:07:11,290 --> 00:07:13,290] 我們要過一輩子的事情
# [00:07:13,290 --> 00:07:15,290] 我不願意造一個dream value
# [00:07:15,290 --> 00:07:16,290] 我覺得一個公司
# [00:07:16,290 --> 00:07:17,290] 以我們做產業來講的話
# [00:07:17,290 --> 00:07:18,290] 我們紮紮實實的
# [00:07:18,290 --> 00:07:19,290] earning per share
# [00:07:19,290 --> 00:07:21,290] 是我們該deliver的東西
# [00:07:21,290 --> 00:07:23,290] dream你們可以去想
# [00:07:23,290 --> 00:07:25,290] 但是不應該price
# [00:07:25,290 --> 00:07:27,290] 我不願意走這個路子
# [00:07:27,290 --> 00:07:29,290] 這會傷到人的
# [00:07:32,290 --> 00:07:34,290] 最後有一個孤兒藥的問題
# [00:07:34,290 --> 00:07:35,290] 跟大家回答一下
# [00:07:35,290 --> 00:07:37,290] 問題是孤兒藥專賣結束後
# [00:07:37,290 --> 00:07:39,290] 一年獲利以及EPS減少多少
# [00:07:39,290 --> 00:07:41,290] 這個我們沒有辦法做預測
# [00:07:41,290 --> 00:07:43,290] 因為其實孤兒藥的
# [00:07:43,290 --> 00:07:44,290] 這個專利結束之後
# [00:07:44,290 --> 00:07:46,290] 它並不是這個藥就消失
# [00:07:46,290 --> 00:07:47,290] 它就不能賣了
# [00:07:47,290 --> 00:07:48,290] 那紡織藥會進來
# [00:07:48,290 --> 00:07:50,290] 究竟會有多少紡織藥進來
# [00:07:50,290 --> 00:07:51,290] 我們也不知道
# [00:07:51,290 --> 00:07:53,290] 其實我想這個
# [00:07:53,290 --> 00:07:54,290] 生技的重點
# [00:07:54,290 --> 00:07:55,290] 應該是剛剛黃總
# [00:07:55,290 --> 00:07:56,290] 跟各位報告的
# [00:07:56,290 --> 00:07:58,290] 就是其實中向有持續
# [00:07:58,290 --> 00:08:00,290] 在做藥這邊的投資
# [00:08:00,290 --> 00:08:01,290] 如果有好的消息的話
# [00:08:01,290 --> 00:08:03,290] 我們會盡快跟大家分享
# [00:08:05,280 --> 00:08:06,280] 因為時間的關係
# [00:08:06,280 --> 00:08:08,280] 所以我們QA進行到現在
# [00:08:08,280 --> 00:08:11,280] 那請各位主管上台
# [00:08:11,280 --> 00:08:13,280] 我們開放三分鐘
# [00:08:13,280 --> 00:08:15,280] 讓各位貴賓能夠拍照
# [00:08:18,280 --> 00:08:26,610] 這邊備有茶點
# [00:08:26,610 --> 00:08:28,610] 供各位貴賓享用
# [00:08:30,610 --> 00:08:33,690] 台北企業團
# [00:08:33,690 --> 00:08:35,690] 聯合法人說明會到此結束
# [00:08:35,690 --> 00:08:37,690] 敬祝各位服務人
# [00:08:37,690 --> 00:08:39,690] 健體健康萬事如意
# [00:08:39,690 --> 00:08:41,690] 她說要問資格
# [00:08:41,690 --> 00:09:20,580] 她說要問資格
# [00:09:20,580 --> 00:09:22,580] 樓上可不可以把燈打亮
# **Transcript file created: /content/drive/My Drive/output/1101台泥_2018Q1_6法人說明會_20180515.txt**
